# %%
import pandas as pd
import pathlib

repo = pathlib.Path(".").resolve().parent
data = repo / "data/processed/llm_evaluation/"

# %%
df =pd.read_csv(data / "eval_results_v6.csv")

# %%
latex_table = df.to_latex(
    index=False,
    escape=False,  # Important for % symbols and other LaTeX commands
    caption='Comparative analysis of GPT-Models',
    label='tab:ml_comparison',
    position='htbp'
)

# %%
print(latex_table)
# Out:
# \begin{table}[htbp]
# \caption{Comparative analysis of GPT-Models}
# \label{tab:ml_comparison}
# \begin{tabular}{lllrrrrrr}
# \toprule
# Modell & Strategie & Aufgabe & Accuracy & Precision & Recall & F1 (macro) & Unknown-Rate & Latenz (s) \\
# \midrule
# gpt-5.5 & combined & critical & 0.866700 & 0.789800 & 0.854200 & 0.813700 & 0.000000 & 7.246000 \\
# gpt-5.5 & separate & critical & 0.766700 & 0.701000 & 0.791700 & 0.712700 & 0.000000 & 4.503000 \\
# gpt-5.5 & combined & sentiment & 0.900000 & 0.752200 & 0.805600 & 0.775000 & 0.000000 & 7.246000 \\
# gpt-5.5 & separate & sentiment & 0.933300 & 0.919400 & 0.819400 & 0.838000 & 0.000000 & 2.780000 \\
# gpt-5.5 & combined & task_type & 0.900000 & 0.720000 & 0.664400 & 0.668200 & 0.000000 & 7.246000 \\
# gpt-5.5 & separate & task_type & 0.866700 & 0.708300 & 0.642200 & 0.649000 & 0.000000 & 3.343000 \\
# \bottomrule
# \end{tabular}
# \end{table}
