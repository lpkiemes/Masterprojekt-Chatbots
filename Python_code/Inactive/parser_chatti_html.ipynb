# %%
from Python_code.modules.paser_chatti_html import extract_with_meta

# %%
from chat_extractor import extract, to_dataframe, to_json
html_pfad = "/home/theo/Schreibtisch/Effekte von Variablen isolieren.html"
# Als Liste von Dicts
history = extract(html_pfad)
history[0]  # → {"speaker": "user", "text": "..."}

# Als pandas DataFrame (mit turn-Spalte)
df = to_dataframe(html_pfad)
df.head()

# Als JSON-Datei speichern
saved_path = to_json(html_pfad)          # → mein_chat.json
to_json("mein_chat.html", "output/verlauf.json") # eigener Pfad

# %%
html_pfad = "/home/theo/Schreibtisch/Gestapelter Barplot Vergleich.html"
# Als Liste von Dicts
history = extract(html_pfad)
history  # → {"speaker": "user", "text": "..."}

# %%
extract_with_meta(html_pfad)
